# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Activity_5_Data_interpretations_using_Histograms_%26_Boxplots_Cual_seria_histograma_de_peso%2C_usa_bins_%3D_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px   #Graficas interactivas
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/antropometria-dataset-1.csv',
                   #sheet_name='Canada by Citizenship',
                   #skiprows=range(20),
                   #skipfooter=2,
                   #engine='openpyxl'
                  )
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
favs = ['folio', 'intp', 'entidad', 'edad', 'meses',
       'ropa', 'emb', 'temb', 'cintura', 'cadera', 'sexo', 'sistol',
       'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var', 'talla']

df.drop(favs, 
        axis=1, #axis One is Column
        inplace=True
       )

df
# Out:
#                               desc_ent   peso
# 0                               PUEBLA  73.70
# 1                              DURANGO  35.65
# 2                       AGUASCALIENTES  54.80
# 3                     DISTRITO FEDERAL  33.40
# 4                               PUEBLA  97.95
# ...                                ...    ...
# 18635  VERACRUZ DE IGNACIO DE LA LLAVE  75.80
# 18636                         CAMPECHE  69.40
# 18637  VERACRUZ DE IGNACIO DE LA LLAVE  46.75
# 18638                          SINALOA  59.05
# 18639                   AGUASCALIENTES  80.00
#
# [18640 rows x 2 columns]

# %%
df_pivot = df.pivot_table('peso', 
               index='desc_ent' 
                              )
df_pivot
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
sns.histplot(df,
             bins=25);
