# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Activity_6_Conclusions_on_filtered_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px   #Graficas interactivas
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Data mining/antropometria-dataset-1.csv',
                   #sheet_name='Canada by Citizenship',
                   #skiprows=range(20),
                   #skipfooter=2,
                   #engine='openpyxl'
                  )
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
favs = ['folio', 'intp', 'entidad', 'edad', 'meses',
       'ropa', 'emb', 'temb', 'cintura', 'cadera', 'sexo', 'sistol',
       'peso', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var', 'talla']

df1 = df.drop(favs, 
        axis=1, #axis One is Column
        #inplace=True
       )

df1
# Out:
#                               desc_ent  diastol
# 0                               PUEBLA    53.25
# 1                              DURANGO    50.00
# 2                       AGUASCALIENTES    41.00
# 3                     DISTRITO FEDERAL    64.00
# 4                               PUEBLA    53.50
# ...                                ...      ...
# 18635  VERACRUZ DE IGNACIO DE LA LLAVE    95.50
# 18636                         CAMPECHE    78.00
# 18637  VERACRUZ DE IGNACIO DE LA LLAVE    66.00
# 18638                          SINALOA   100.00
# 18639                   AGUASCALIENTES   150.00
#
# [18640 rows x 2 columns]

# %%
df1_pivot = df.pivot_table('diastol', 
               index='desc_ent' 
                              )
df1_pivot
# Out:
#                                    diastol
# desc_ent
# AGUASCALIENTES                   78.553435
# BAJA CALIFORNIA                  76.773493
# BAJA CALIFORNIA SUR              75.676415
# CAMPECHE                         75.280499
# CHIAPAS                          73.085938
# CHIHUAHUA                        75.625639
# COAHUILA DE ZARAGOZA             76.919526
# COLIMA                           75.053840
# DISTRITO FEDERAL                 74.341199
# DURANGO                          77.431034
# GUANAJUATO                       75.608761
# GUERRERO                         74.300394
# HIDALGO                          74.262548
# JALISCO                          75.752814
# MEXICO                           74.017660
# MICHOACAN DE OCAMPO              76.372287
# MORELOS                          73.636691
# NAYARIT                          73.370000
# NUEVO LEON                       79.456404
# OAXACA                           74.150833
# ...

# %%
sns.histplot(df1,
             bins=15);

# %%
favs2 = ['folio', 'intp', 'entidad', 'edad', 'meses',
       'ropa', 'emb', 'temb', 'cintura', 'cadera',
       'peso', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var', 'talla']

df2 = df.drop(favs2, 
        axis=1, #axis One is Column
        #inplace=True
       )

df2
# Out:
#                               desc_ent  sexo  sistol  diastol
# 0                               PUEBLA     2   63.25    53.25
# 1                              DURANGO     2   70.00    50.00
# 2                       AGUASCALIENTES     2   70.50    41.00
# 3                     DISTRITO FEDERAL     1   71.00    64.00
# 4                               PUEBLA     2   72.00    53.50
# ...                                ...   ...     ...      ...
# 18635  VERACRUZ DE IGNACIO DE LA LLAVE     2  221.00    95.50
# 18636                         CAMPECHE     2  222.25    78.00
# 18637  VERACRUZ DE IGNACIO DE LA LLAVE     1  230.00    66.00
# 18638                          SINALOA     2  235.00   100.00
# 18639                   AGUASCALIENTES     2  240.00   150.00
#
# [18640 rows x 4 columns]

# %%
sns.lmplot(x = 'sistol', 
           y = 'diastol',
           data = df,
           hue = 'sexo',
           fit_reg = False
           )   
plt.title('my title', fontsize = 17)  ;
#  fit_reg = linea de regresión

# %%
favs3 = ['folio', 'intp', 'entidad', 'edad', 'meses',
       'ropa', 'emb', 'temb', 'sexo', 'cadera', 'sistol', 'diastol',
       'peso', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var', 'talla']

df3 = df.drop(favs3, 
        axis=1, #axis One is Column
        #inplace=True
       )

df3
# Out:
#                               desc_ent  cintura
# 0                               PUEBLA    98.70
# 1                              DURANGO    64.00
# 2                       AGUASCALIENTES    67.60
# 3                     DISTRITO FEDERAL    60.60
# 4                               PUEBLA   113.00
# ...                                ...      ...
# 18635  VERACRUZ DE IGNACIO DE LA LLAVE    93.00
# 18636                         CAMPECHE   103.05
# 18637  VERACRUZ DE IGNACIO DE LA LLAVE    71.35
# 18638                          SINALOA    99.95
# 18639                   AGUASCALIENTES   108.15
#
# [18640 rows x 2 columns]

# %%
sns.boxplot(data = df3.loc[:, 'cintura'])     ;
plt.title('Cintura')
plt.show()

# %% [markdown]
# If 'sexo 2 = mujer', and 'sexo 1 = hombre', what would the scatter plot be when  x = mujer_peso   y = mujer_cintura?

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
favs4 = ['folio', 'intp', 'entidad', 'desc_ent', 'edad', 'meses',
       'ropa', 'talla', 'emb', 'temb', 'cadera', 'sistol',
       'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var']

df4 = df.drop(favs4, 
        axis=1, #axis One is Column
        #inplace=True
       )
df5 = df4[df4['sexo']==2]
df5
# Out:
#        sexo   peso  cintura
# 0         2  73.70    98.70
# 1         2  35.65    64.00
# 2         2  54.80    67.60
# 4         2  97.95   113.00
# 6         2  31.95    57.30
# ...     ...    ...      ...
# 18633     2  75.40    94.10
# 18635     2  75.80    93.00
# 18636     2  69.40   103.05
# 18638     2  59.05    99.95
# 18639     2  80.00   108.15
#
# [10486 rows x 3 columns]

# %%
sns.lmplot(x = 'peso', 
           y = 'cintura',
           data = df5,
           #hue = 'sexo',
           fit_reg = False
           )   
plt.title('my title', fontsize = 17)  ;
#  fit_reg = linea de regresión

# %% [markdown]
# If 'sexo 2 = mujer', and 'sexo 1 = hombre', which is the histogram of hombre_peso?

# %%
favs5 = ['folio', 'intp', 'entidad', 'desc_ent', 'edad', 'meses',
       'ropa', 'talla', 'emb', 'temb', 'cadera', 'sistol', 'cintura',
       'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var']

df6 = df.drop(favs5, 
        axis=1, #axis One is Column
        #inplace=True
       )
df7 = df6[df6['sexo']==1]
df7
# Out:
#        sexo     peso
# 3         1   33.400
# 5         1   31.900
# 9         1   48.025
# 17        1   31.500
# 21        1   59.850
# ...     ...      ...
# 18626     1   77.350
# 18627     1   68.600
# 18630     1   57.050
# 18634     1  118.850
# 18637     1   46.750
#
# [8154 rows x 2 columns]

# %%
df8 = df7.drop('sexo', axis=1)
df8
# Out:
#           peso
# 3       33.400
# 5       31.900
# 9       48.025
# 17      31.500
# 21      59.850
# ...        ...
# 18626   77.350
# 18627   68.600
# 18630   57.050
# 18634  118.850
# 18637   46.750
#
# [8154 rows x 1 columns]

# %%
sns.histplot(df8,
             bins=15);

# %%
plt.hist(df8,
             bins=15);
