# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Activity_5_Data_interpretations_using_Histograms_%26_Boxplots_what_would_be_the_line_plot_of_%22CADERA%22_in_SEXO_1%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px   #Graficas interactivas
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/antropometria-dataset-1.csv',
                   #sheet_name='Canada by Citizenship',
                   #skiprows=range(20),
                   #skipfooter=2,
                   #engine='openpyxl'
                  )
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
df_pivot = df.pivot_table('peso', 
               index='desc_ent', 
               columns='sexo'
               )
df_pivot
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# MICHOACAN DE OCAMPO              66.374612  63.784311
# ...

# %%
favs = ['folio', 'intp', 'entidad', 'edad', 'meses',
       'ropa', 'emb', 'temb', 'cintura', 'peso', 'sistol',
       'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
       'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var', 'talla']

df.drop(favs, 
        axis=1, #axis One is Column
        inplace=True
       )

df.head(6)
# Out:
#            desc_ent  sexo  cadera
# 0            PUEBLA     2   106.0
# 1           DURANGO     2    75.0
# 2    AGUASCALIENTES     2    94.3
# 3  DISTRITO FEDERAL     1    72.2
# 4            PUEBLA     2   127.0
# 5   SAN LUIS POTOSI     1    75.0

# %%
df2 = df.drop(df[df['sexo']==2].index)
df2
# Out:
#                               desc_ent  sexo  cadera
# 3                     DISTRITO FEDERAL     1   72.20
# 5                      SAN LUIS POTOSI     1   75.00
# 9                  BAJA CALIFORNIA SUR     1   81.65
# 17                           ZACATECAS     1   72.00
# 21                              SONORA     1   98.40
# ...                                ...   ...     ...
# 18626                          MORELOS     1   99.25
# 18627  VERACRUZ DE IGNACIO DE LA LLAVE     1  100.05
# 18630                           PUEBLA     1   93.85
# 18634                   AGUASCALIENTES     1  122.55
# 18637  VERACRUZ DE IGNACIO DE LA LLAVE     1   86.00
#
# [8154 rows x 3 columns]

# %%
df3 = df2.drop(['sexo'], 
                axis = 1)
df3
# Out:
#                               desc_ent  cadera
# 0                               PUEBLA   106.0
# 1                              DURANGO    75.0
# 2                       AGUASCALIENTES    94.3
# 4                               PUEBLA   127.0
# 6                               PUEBLA    70.1
# ...                                ...     ...
# 18633              MICHOACAN DE OCAMPO   104.1
# 18635  VERACRUZ DE IGNACIO DE LA LLAVE   113.0
# 18636                         CAMPECHE   113.7
# 18638                          SINALOA    94.8
# 18639                   AGUASCALIENTES   120.0
#
# [10486 rows x 2 columns]

# %%
df3_pivot = df3.pivot_table('cadera', 
               index='desc_ent',
               aggfunc='median' 
               )
df3_pivot
# Out:
#                                   cadera
# desc_ent
# AGUASCALIENTES                   100.000
# BAJA CALIFORNIA                  100.500
# BAJA CALIFORNIA SUR              101.800
# CAMPECHE                          99.975
# CHIAPAS                           94.550
# CHIHUAHUA                        100.600
# COAHUILA DE ZARAGOZA             102.400
# COLIMA                           102.600
# DISTRITO FEDERAL                  99.900
# DURANGO                           98.500
# GUANAJUATO                        98.000
# GUERRERO                          96.550
# HIDALGO                           96.100
# JALISCO                          101.050
# MEXICO                            96.475
# MICHOACAN DE OCAMPO               99.150
# MORELOS                           98.800
# NAYARIT                           99.200
# NUEVO LEON                       100.700
# OAXACA                            95.150
# PUEBLA                            97.000
# QUERETARO                         97.600
# ...

# %%
df3_pivot.plot(kind='line', 
              figsize=(8, 6)
             )

plt.title('Box plot')
plt.ylabel('Y')

plt.show()
