# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Clase_5_Canada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px   #Graficas interactivas
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
df = pd.read_excel('/content/drive/MyDrive/Canada.xlsx',
                   sheet_name='Canada by Citizenship',
                   skiprows=range(20),
                   skipfooter=2,
                   engine='openpyxl'
                  )

# %%
df.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 43 columns]

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
y =   [   1980,       1981, ]

# %%
years = [1980,       1981,       1982,
             1983,       1984,       1985,       1986,       1987,       1988,
             1989,       1990,       1991,       1992,       1993,       1994,
             1995,       1996,       1997,       1998,       1999,       2000,
             2001,       2002,       2003,       2004,       2005,       2006,
             2007,       2008,       2009,       2010,       2011,       2012,
             2013]

# %%
df[['OdName',   1980,       1981,       1982,
             1983,       1984,       1985,       1986,       1987,       1988,
             1989,       1990,       1991,       1992,       1993,       1994,
             1995,       1996,       1997,       1998,       1999,       2000,
             2001,       2002,       2003,       2004,       2005,       2006,
             2007,       2008,       2009,       2010,       2011,       2012,
             2013]]
# Out:
#              OdName  1980  1981  1982  1983  1984  1985  1986  1987  1988  \
# 0       Afghanistan    16    39    39    47    71   340   496   741   828
# 1           Albania     1     0     0     0     0     0     1     2     2
# 2           Algeria    80    67    71    69    63    44    69   132   242
# 3    American Samoa     0     1     0     0     0     0     0     1     0
# 4           Andorra     0     0     0     0     0     0     2     0     0
# ..              ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162  3404  7583  5907  2741  1406  1411
# 191  Western Sahara     0     0     0     0     0     0     0     0     0
# 192           Yemen     1     2     1     6     0    18     7    12     7
# 193          Zambia    11    17    11     7    16     9    15    23    44
# 194        Zimbabwe    72   114   102    44    32    29    43    68    99
#
#      ...  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# ...

# %%
df.set_index('OdName', inplace = True)

# %%
df.head(2)
# Out:
#                    Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan  Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#              DEV             DevName  1980  1981  ...  2004  2005  2006  2007  \
# OdName                                            ...
# Afghanistan  902  Developing regions    16    39  ...  2978  3436  3009  2652
# Albania      901   Developed regions     1     0  ...  1450  1223   856   702
#
#              2008  2009  2010  2011  2012  2013
# OdName
# Afghanistan  2111  1746  1758  2203  2635  2004
# Albania       560   716   561   539   620   603
#
# [2 rows x 42 columns]

# %%
df_CI = df.loc[['China', 'India'], years].transpose()
df_CI
# Out:
# OdName  China  India
# 1980     5123   8880
# 1981     6682   8670
# 1982     3308   8147
# 1983     1863   7338
# 1984     1527   5704
# 1985     1816   4211
# 1986     1960   7150
# 1987     2643  10189
# 1988     2758  11522
# 1989     4323  10343
# 1990     8076  12041
# 1991    14255  13734
# 1992    10846  13673
# 1993     9817  21496
# 1994    13128  18620
# 1995    14398  18489
# 1996    19415  23859
# 1997    20475  22268
# 1998    21049  17241
# 1999    30069  18974
# 2000    35529  28572
# 2001    36434  31223
# 2002    31961  31889
# 2003    36439  27155
# 2004    36619  28235
# 2005    42584  36210
# 2006    33518  33848
# 2007    27642  28742
# 2008    30037  28261
# 2009    29622  29456
# 2010    30391  34235
# 2011    28502  27509
# 2012    33024  30933
# 2013    34129  33087

# %%
df_CI.plot(kind = 'line')
