# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/LendingClub_Team_3%20Final%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(color_codes=True)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##3.1 Realizar la exploración inicial de dataset##

# %%
df = pd.read_csv("/content/drive/MyDrive/LCS.csv")

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#    Unnamed: 0  mths_since_recent_inq  num_tl_120dpd_2m  mo_sin_old_il_acct  \
# 0           1                      4                 0                 148
# 1           2                      0                 0                 113
# 2           3                     10                 0                 125
# 3           4                      1                 0                 128
# 4           5                     10                 0                 142
#
#    bc_util  percent_bc_gt_75  bc_open_to_buy  mths_since_recent_bc  \
# 0     37.2               0.0          1506.0                     4
# 1     27.1               7.7         57830.0                     2
# 2     55.9              50.0          2737.0                   101
# 3     77.5              60.0          4567.0                     4
# 4    102.9             100.0             0.0                    12
#
#    pct_tl_nvr_dlq  avg_cur_bal  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0            76.9        20701                   128                      3
# 1            97.4         9733                   192                      2
# 2           100.0        31617                   184                     14
# 3            96.6        27644                   210                      4
# 4            96.3        30030                   306                     10
#
#    num_rev_accts  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  mo_sin_rcnt_tl  \
# 0              9         722.0     144904.0            9300.0               3
# 1             27           0.0     204396.0          111800.0               2
# 2              7           0.0     189699.0           14000.0              14
# 3             19           0.0     331730.0           34000.0               4
# 4             16           0.0     360358.0           94200.0              10
#
#    num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  num_bc_tl  \
# 0                      2               2                4          5
# 1                      0               5                5         17
# 2                      0               2                3          4
# 3                      0               4                6          9
# 4                      0               4                6          5
#
#    num_il_tl  num_op_rev_tl  num_rev_tl_bal_gt_0  num_tl_30dpd  \
# 0          3              4                    4             0
# 1          6             20                    5             0
# 2          6              4                    3             0
# 3         10              7                    6             0
# 4          7              9                    6             0
#
#    num_tl_90g_dpd_24m  num_tl_op_past_12m  tot_hi_cred_lim  \
# 0                   0                   3         178050.0
# 1                   0                   2         314017.0
# 2                   0                   0         218418.0
# 3                   0                   4         439570.0
# 4                   0                   2         388852.0
#
#    total_il_high_credit_limit  num_bc_sats  num_sats  acc_open_past_24mths  \
# 0                     13734.0            2         7                     4
# 1                     24667.0           13        22                     4
# 2                     14877.0            2         6                     6
# 3                     88097.0            5        12                    10
# 4                     46452.0            4        12                     6
#
#    mort_acc  total_bal_ex_mort  total_bc_limit  revol_util    dti  \
# 0         1             7746.0          2400.0        29.7   5.91
# 1         4            39475.0         79300.0        19.2  16.06
# 2         5            18696.0          6200.0        56.2  10.78
# 3         6            95768.0         20300.0        64.5  25.37
# 4         4           116762.0         31500.0        84.5  14.67
#
#    pub_rec_bankruptcies  collections_12_mths_ex_med  chargeoff_within_12_mths  \
# 0                     0                           0                         0
# 1                     0                           0                         0
# 2                     0                           0                         0
# 3                     0                           0                         0
# 4                     0                           0                         0
#
#    tax_liens  inq_last_6mths  delinq_2yrs  open_acc  pub_rec  total_acc  \
# 0          0               1            0         7        0         13
# 1          0               4            1        22        0         38
# 2          0               0            0         6        0         18
# 3          0               3            1        12        0         35
# 4          0               0            0        12        0         27
#
#    acc_now_delinq  delinq_amnt  annual_inc  loan_amnt  funded_amnt  \
# 0               0            0     55000.0       3600         3600
# 1               0            0     65000.0      24700        24700
# 2               0            0     63000.0      20000        20000
# 3               0            0    104433.0      10400        10400
# 4               0            0    180000.0      20000        20000
#
#    funded_amnt_inv  int_rate  installment  fico_range_low  fico_range_high  \
# 0           3600.0     13.99       123.03             675              679
# 1          24700.0     11.99       820.28             715              719
# 2          20000.0     10.78       432.66             695              699
# 3          10400.0     22.45       289.91             695              699
# 4          20000.0      9.17       637.58             680              684
#
#    revol_bal  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# 0     2765.0        0.0            0.0   4421.723917          4421.72
# 1    21470.0        0.0            0.0  25679.660000         25679.66
# 2     7869.0        0.0            0.0  22705.924294         22705.92
# 3    21929.0        0.0            0.0  11740.500000         11740.50
# 4    87329.0        0.0            0.0  21393.800000         21393.80
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0           3600.0         821.72                 0.0         0.0
# 1          24700.0         979.66                 0.0         0.0
# 2          20000.0        2705.92                 0.0         0.0
# 3          10400.0        1340.50                 0.0         0.0
# 4          20000.0        1393.80                 0.0         0.0
#
#    collection_recovery_fee  last_pymnt_amnt  last_fico_range_high  \
# 0                      0.0           122.67                 564.0
# 1                      0.0           926.35                 699.0
# 2                      0.0         15813.30                 704.0
# 3                      0.0         10128.96                 704.0
# 4                      0.0         15681.05                 654.0
#
#    last_fico_range_low  policy_code          id        term grade sub_grade  \
# 0                560.0          1.0  68407277.0   36 months     C        C4
# 1                695.0          1.0  68355089.0   36 months     C        C1
# 2                700.0          1.0  68341763.0   60 months     B        B4
# 3                700.0          1.0  68476807.0   60 months     F        F1
# 4                650.0          1.0  68476668.0   36 months     B        B2
#
#                                  emp_title emp_length home_ownership  \
# 0                                  leadman  10+ years       MORTGAGE
# 1                                 Engineer  10+ years       MORTGAGE
# 2                             truck driver  10+ years       MORTGAGE
# 3                      Contract Specialist    3 years       MORTGAGE
# 4  Vice President of Recruiting Operations  10+ years       MORTGAGE
#
#   verification_status   issue_d loan_status pymnt_plan             purpose  \
# 0        Not Verified  Dec-2015  Fully Paid          n  debt_consolidation
# 1        Not Verified  Dec-2015  Fully Paid          n      small_business
# 2        Not Verified  Dec-2015  Fully Paid          n    home_improvement
# 3     Source Verified  Dec-2015  Fully Paid          n      major_purchase
# 4        Not Verified  Dec-2015  Fully Paid          n  debt_consolidation
#
#                 title zip_code addr_state earliest_cr_line  \
# 0  Debt consolidation    190xx         PA         Aug-2003
# 1            Business    577xx         SD         Dec-1999
# 2                 NaN    605xx         IL         Aug-2000
# 3      Major purchase    174xx         PA         Jun-1998
# 4  Debt consolidation    550xx         MN         Jun-1990
#
#   initial_list_status last_pymnt_d last_credit_pull_d application_type  \
# 0                   w     Jan-2019           Mar-2019       Individual
# 1                   w     Jun-2016           Mar-2019       Individual
# 2                   w     Jun-2017           Mar-2019        Joint App
# 3                   w     Jul-2016           Mar-2018       Individual
# 4                   f     Nov-2016           Mar-2019       Individual
#
#   hardship_flag disbursement_method debt_settlement_flag
# 0             N                Cash                    N
# 1             N                Cash                    N
# 2             N                Cash                    N
# 3             N                Cash                    N
# 4             N                Cash                    N

# %%
df.describe()
# Out:
#          Unnamed: 0  mths_since_recent_inq  num_tl_120dpd_2m  \
# count  1.734366e+06           1.734366e+06      1.734366e+06
# mean   8.671835e+05           7.085525e+00      6.336609e-04
# std    5.006685e+05           5.968216e+00      2.721220e-02
# min    1.000000e+00           0.000000e+00      0.000000e+00
# 25%    4.335922e+05           2.000000e+00      0.000000e+00
# 50%    8.671835e+05           6.000000e+00      0.000000e+00
# 75%    1.300775e+06           1.100000e+01      0.000000e+00
# max    1.734366e+06           2.400000e+01      7.000000e+00
#
#        mo_sin_old_il_acct       bc_util  percent_bc_gt_75  bc_open_to_buy  \
# count        1.734366e+06  1.734366e+06      1.734366e+06    1.734366e+06
# mean         1.254348e+02  5.686563e+01      4.113868e+01    1.184414e+04
# std          5.324958e+01  2.855699e+01      3.589811e+01    1.709988e+04
# min          0.000000e+00  0.000000e+00      0.000000e+00    0.000000e+00
# 25%          9.500000e+01  3.420000e+01      0.000000e+00    1.742000e+03
# 50%          1.300000e+02  5.880000e+01      3.330000e+01    5.725000e+03
# 75%          1.530000e+02  8.190000e+01      6.670000e+01    1.491400e+04
# max          9.990000e+02  3.396000e+02      1.000000e+02    7.111400e+05
#
#        mths_since_recent_bc  pct_tl_nvr_dlq   avg_cur_bal  \
# count          1.734366e+06    1.734366e+06  1.734366e+06
# mean           2.333517e+01    9.423194e+01  1.380339e+04
# std            3.036925e+01    8.787750e+00  1.606150e+04
# min            0.000000e+00    0.000000e+00  0.000000e+00
# 25%            6.000000e+00    9.170000e+01  3.275000e+03
# 50%            1.300000e+01    9.830000e+01  7.897000e+03
# 75%            2.800000e+01    1.000000e+02  1.924500e+04
# max            6.560000e+02    1.000000e+02  6.232290e+05
#
#        mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  num_rev_accts  \
# count          1.734366e+06           1.734366e+06   1.734366e+06
# mean           1.796456e+02           1.271406e+01   1.441183e+01
# std            9.583801e+01           1.556097e+01   8.118446e+00
# min            1.000000e+00           0.000000e+00   1.000000e+00
# 25%            1.160000e+02           4.000000e+00   9.000000e+00
# 50%            1.620000e+02           8.000000e+00   1.300000e+01
# 75%            2.290000e+02           1.600000e+01   1.900000e+01
# max            9.010000e+02           5.020000e+02   1.510000e+02
#
#        tot_coll_amt   tot_cur_bal  total_rev_hi_lim  mo_sin_rcnt_tl  \
# count  1.734366e+06  1.734366e+06      1.734366e+06    1.734366e+06
# mean   2.501747e+02  1.495108e+05      3.498314e+04    7.236972e+00
# std    9.520469e+03  1.617225e+05      3.605008e+04    6.947296e+00
# min    0.000000e+00  0.000000e+00      1.000000e+02    0.000000e+00
# 25%    0.000000e+00  3.248000e+04      1.510000e+04    3.000000e+00
# 50%    0.000000e+00  8.968700e+04      2.600000e+04    5.000000e+00
# 75%    0.000000e+00  2.230350e+05      4.380000e+04    1.000000e+01
# max    9.152545e+06  9.971659e+06      9.999999e+06    1.940000e+02
#
#        num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl     num_bc_tl  \
# count           1.734366e+06    1.734366e+06     1.734366e+06  1.734366e+06
# mean            5.413379e-01    3.703367e+00     5.655965e+00  7.932635e+00
# std             1.404233e+00    2.272151e+00     3.281836e+00  4.745162e+00
# min             0.000000e+00    0.000000e+00     0.000000e+00  1.000000e+00
# 25%             0.000000e+00    2.000000e+00     3.000000e+00  5.000000e+00
# 50%             0.000000e+00    3.000000e+00     5.000000e+00  7.000000e+00
# 75%             0.000000e+00    5.000000e+00     7.000000e+00  1.000000e+01
# max             4.200000e+01    4.800000e+01     5.900000e+01  8.600000e+01
#
#           num_il_tl  num_op_rev_tl  num_rev_tl_bal_gt_0  num_tl_30dpd  \
# count  1.734366e+06   1.734366e+06         1.734366e+06  1.734366e+06
# mean   8.936057e+00   8.510380e+00         5.675346e+00  2.787762e-03
# std    7.434365e+00   4.735552e+00         3.290768e+00  5.586884e-02
# min    1.000000e+00   1.000000e+00         0.000000e+00  0.000000e+00
# 25%    4.000000e+00   5.000000e+00         3.000000e+00  0.000000e+00
# 50%    7.000000e+00   8.000000e+00         5.000000e+00  0.000000e+00
# 75%    1.200000e+01   1.100000e+01         7.000000e+00  0.000000e+00
# max    1.590000e+02   9.100000e+01         5.900000e+01  4.000000e+00
#
#        num_tl_90g_dpd_24m  num_tl_op_past_12m  tot_hi_cred_lim  \
# count        1.734366e+06        1.734366e+06     1.734366e+06
# mean         7.809021e-02        2.224467e+00     1.862886e+05
# std          4.700819e-01        1.837033e+00     1.820948e+05
# min          0.000000e+00        0.000000e+00     2.000000e+02
# 25%          0.000000e+00        1.000000e+00     5.550000e+04
# 50%          0.000000e+00        2.000000e+00     1.256190e+05
# 75%          0.000000e+00        3.000000e+00     2.683060e+05
# max          3.900000e+01        3.200000e+01     9.999999e+06
#
#        total_il_high_credit_limit   num_bc_sats      num_sats  \
# count                1.734366e+06  1.734366e+06  1.734366e+06
# mean                 4.651719e+04  4.789860e+00  1.207776e+01
# std                  4.566604e+04  2.894984e+00  5.672723e+00
# min                  0.000000e+00  0.000000e+00  1.000000e+00
# 25%                  1.778500e+04  3.000000e+00  8.000000e+00
# 50%                  3.515000e+04  4.000000e+00  1.100000e+01
# 75%                  6.161200e+04  6.000000e+00  1.500000e+01
# max                  2.118996e+06  7.100000e+01  1.010000e+02
#
#        acc_open_past_24mths      mort_acc  total_bal_ex_mort  total_bc_limit  \
# count          1.734366e+06  1.734366e+06       1.734366e+06    1.734366e+06
# mean           4.874020e+00  1.632379e+00       5.350815e+04    2.347864e+04
# std            3.151277e+00  1.934846e+00       5.080068e+04    2.311224e+04
# min            0.000000e+00  0.000000e+00       0.000000e+00    1.000000e+02
# 25%            3.000000e+00  0.000000e+00       2.298500e+04    8.500000e+03
# 50%            4.000000e+00  1.000000e+00       4.009500e+04    1.650000e+04
# 75%            6.000000e+00  3.000000e+00       6.699100e+04    3.060000e+04
# max            6.400000e+01  9.400000e+01       3.408095e+06    1.569000e+06
#
#          revol_util           dti  pub_rec_bankruptcies  \
# count  1.734366e+06  1.734366e+06          1.734366e+06
# mean   4.924941e+01  1.934619e+01          1.357361e-01
# std    2.428461e+01  1.433627e+01          3.759616e-01
# min    0.000000e+00 -1.000000e+00          0.000000e+00
# 25%    3.070000e+01  1.246000e+01          0.000000e+00
# 50%    4.900000e+01  1.831000e+01          0.000000e+00
# 75%    6.770000e+01  2.493000e+01          0.000000e+00
# max    3.666000e+02  9.990000e+02          1.200000e+01
#
#        collections_12_mths_ex_med  chargeoff_within_12_mths     tax_liens  \
# count                1.734366e+06              1.734366e+06  1.734366e+06
# mean                 1.770330e-02              8.712117e-03  4.957835e-02
# std                  1.459580e-01              1.049478e-01  3.939546e-01
# min                  0.000000e+00              0.000000e+00  0.000000e+00
# 25%                  0.000000e+00              0.000000e+00  0.000000e+00
# 50%                  0.000000e+00              0.000000e+00  0.000000e+00
# 75%                  0.000000e+00              0.000000e+00  0.000000e+00
# max                  2.000000e+01              9.000000e+00  8.500000e+01
#
#        inq_last_6mths   delinq_2yrs      open_acc       pub_rec     total_acc  \
# count    1.734366e+06  1.734366e+06  1.734366e+06  1.734366e+06  1.734366e+06
# mean     6.107875e-01  3.089953e-01  1.210490e+01  2.082848e-01  2.524029e+01
# std      8.656246e-01  8.640355e-01  5.676099e+00  5.895329e-01  1.203975e+01
# min      0.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00  3.000000e+00
# 25%      0.000000e+00  0.000000e+00  8.000000e+00  0.000000e+00  1.600000e+01
# 50%      0.000000e+00  0.000000e+00  1.100000e+01  0.000000e+00  2.300000e+01
# 75%      1.000000e+00  0.000000e+00  1.500000e+01  0.000000e+00  3.200000e+01
# max      8.000000e+00  3.900000e+01  1.010000e+02  8.600000e+01  1.760000e+02
#
#        acc_now_delinq   delinq_amnt    annual_inc     loan_amnt   funded_amnt  \
# count    1.734366e+06  1.734366e+06  1.734366e+06  1.734366e+06  1.734366e+06
# mean     4.274184e-03  1.131784e+01  7.976987e+04  1.526159e+04  1.526157e+04
# std      7.078195e-02  6.635377e+02  1.139537e+05  9.205165e+03  9.205157e+03
# min      0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+03  1.000000e+03
# 25%      0.000000e+00  0.000000e+00  4.800000e+04  8.000000e+03  8.000000e+03
# 50%      0.000000e+00  0.000000e+00  6.700000e+04  1.320000e+04  1.320000e+04
# 75%      0.000000e+00  0.000000e+00  9.500000e+04  2.000000e+04  2.000000e+04
# max      1.400000e+01  1.384740e+05  1.100000e+08  4.000000e+04  4.000000e+04
#
#        funded_amnt_inv      int_rate   installment  fico_range_low  \
# count     1.734366e+06  1.734366e+06  1.734366e+06    1.734366e+06
# mean      1.525636e+04  1.319852e+01  4.515647e+02    6.980741e+02
# std       9.203053e+03  4.866017e+00  2.674211e+02    3.264122e+01
# min       7.250000e+02  5.310000e+00  4.930000e+00    6.600000e+02
# 25%       8.000000e+03  9.670000e+00  2.576600e+02    6.750000e+02
# 50%       1.320000e+04  1.269000e+01  3.840900e+02    6.900000e+02
# 75%       2.000000e+04  1.602000e+01  6.003600e+02    7.150000e+02
# max       4.000000e+04  3.099000e+01  1.719830e+03    8.450000e+02
#
#        fico_range_high     revol_bal     out_prncp  out_prncp_inv  \
# count     1.734366e+06  1.734366e+06  1.734366e+06   1.734366e+06
# mean      7.020742e+02  1.645681e+04  4.336762e+03   4.335812e+03
# std       3.264182e+01  2.193209e+04  7.475132e+03   7.474208e+03
# min       6.640000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       6.790000e+02  6.036000e+03  0.000000e+00   0.000000e+00
# 50%       6.940000e+02  1.137400e+04  0.000000e+00   0.000000e+00
# 75%       7.190000e+02  2.019300e+04  6.484670e+03   6.480750e+03
# max       8.500000e+02  2.568995e+06  4.000000e+04   4.000000e+04
#
#         total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# count  1.734366e+06     1.734365e+06     1.734365e+06   1.734365e+06
# mean   1.216475e+04     1.216012e+04     9.553964e+03   2.458805e+03
# std    1.000180e+04     9.998054e+03     8.409725e+03   2.714844e+03
# min    0.000000e+00     0.000000e+00     0.000000e+00   0.000000e+00
# 25%    4.510593e+03     4.508850e+03     3.000000e+03   7.315500e+02
# 50%    9.383515e+03     9.379710e+03     7.000000e+03   1.541680e+03
# 75%    1.711198e+04     1.710464e+04     1.400000e+04   3.144780e+03
# max    6.329688e+04     6.329688e+04     4.000000e+04   2.819250e+04
#
#        total_rec_late_fee    recoveries  collection_recovery_fee  \
# count        1.734365e+06  1.734365e+06             1.734365e+06
# mean         1.518921e+00  1.504738e+02             2.525078e+01
# std          1.191520e+01  7.663832e+02             1.341763e+02
# min         -9.500000e-09  0.000000e+00             0.000000e+00
# 25%          0.000000e+00  0.000000e+00             0.000000e+00
# 50%          0.000000e+00  0.000000e+00             0.000000e+00
# 75%          0.000000e+00  0.000000e+00             0.000000e+00
# max          1.484340e+03  3.985955e+04             7.174719e+03
#
#        last_pymnt_amnt  last_fico_range_high  last_fico_range_low  \
# count     1.734365e+06          1.734365e+06         1.734365e+06
# mean      3.548850e+03          6.869356e+02         6.750340e+02
# std       6.140644e+03          7.248599e+01         1.098760e+02
# min       0.000000e+00          0.000000e+00         0.000000e+00
# 25%       3.155000e+02          6.540000e+02         6.500000e+02
# 50%       6.138000e+02          6.990000e+02         6.950000e+02
# 75%       4.036910e+03          7.340000e+02         7.300000e+02
# max       4.219205e+04          8.500000e+02         8.450000e+02
#
#        policy_code            id
# count    1734365.0  1.734365e+06
# mean           1.0  8.189442e+07
# std            0.0  4.428664e+07
# min            1.0  5.612100e+04
# 25%            1.0  4.669490e+07
# 50%            1.0  8.374926e+07
# 75%            1.0  1.249047e+08
# max            1.0  1.456473e+08

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# mths_since_recent_inq     0
# num_tl_120dpd_2m          0
# mo_sin_old_il_acct        0
# bc_util                   0
#                          ..
# last_credit_pull_d       30
# application_type          1
# hardship_flag             1
# disbursement_method       1
# debt_settlement_flag      1
# Length: 93, dtype: int64

# %% [markdown]
# ##Limpieza de Datos##

# %%
df.dropna(how='all').count()['loan_status']
# Out:
# 1734365

# %%
pd.set_option('display.max_rows', None)
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# emp_title                     119050
# emp_length                    105006
# title                          18538
# last_pymnt_d                    1704
# last_credit_pull_d                30
# zip_code                           2
# total_rec_int                      1
# total_rec_late_fee                 1
# recoveries                         1
# collection_recovery_fee            1
# sub_grade                          1
# total_rec_prncp                    1
# last_pymnt_amnt                    1
# last_fico_range_high               1
# last_fico_range_low                1
# policy_code                        1
# term                               1
# grade                              1
# total_pymnt_inv                    1
# debt_settlement_flag               1
# id                                 1
# home_ownership                     1
# addr_state                         1
# verification_status                1
# hardship_flag                      1
# application_type                   1
# initial_list_status                1
# earliest_cr_line                   1
# disbursement_method                1
# purpose                            1
# loan_status                        1
# issue_d                            1
# pymnt_plan                         1
# fico_range_low                     0
# loan_amnt                          0
# funded_amnt                        0
# funded_amnt_inv                    0
# int_rate                           0
# installment                        0
# revol_bal                          0
# fico_range_high                    0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# delinq_amnt                        0
# annual_inc                         0
# Unnamed: 0                         0
# mths_since_recent_inq              0
# num_rev_accts                      0
# num_il_tl                          0
# num_bc_tl                          0
# num_actv_rev_tl                    0
# num_actv_bc_tl                     0
# num_accts_ever_120_pd              0
# mo_sin_rcnt_tl                     0
# total_rev_hi_lim                   0
# tot_cur_bal                        0
# tot_coll_amt                       0
# mo_sin_rcnt_rev_tl_op              0
# total_acc                          0
# mo_sin_old_rev_tl_op               0
# avg_cur_bal                        0
# pct_tl_nvr_dlq                     0
# mths_since_recent_bc               0
# bc_open_to_buy                     0
# percent_bc_gt_75                   0
# bc_util                            0
# mo_sin_old_il_acct                 0
# num_tl_120dpd_2m                   0
# num_op_rev_tl                      0
# num_rev_tl_bal_gt_0                0
# num_tl_30dpd                       0
# num_tl_90g_dpd_24m                 0
# pub_rec                            0
# open_acc                           0
# delinq_2yrs                        0
# inq_last_6mths                     0
# tax_liens                          0
# chargeoff_within_12_mths           0
# collections_12_mths_ex_med         0
# pub_rec_bankruptcies               0
# dti                                0
# revol_util                         0
# total_bc_limit                     0
# total_bal_ex_mort                  0
# mort_acc                           0
# acc_open_past_24mths               0
# num_sats                           0
# num_bc_sats                        0
# total_il_high_credit_limit         0
# tot_hi_cred_lim                    0
# num_tl_op_past_12m                 0
# acc_now_delinq                     0
# dtype: int64

# %%
features_to_select = [
    "loan_status",
    "loan_amnt",
    "int_rate",
    "dti",
    "fico_range_low",
    "fico_range_high",
    "term",
    "tot_hi_cred_lim",
    "total_acc",
    "total_bal_ex_mort",
    "total_bc_limit",
    "total_rec_late_fee",
    "percent_bc_gt_75",
    "avg_cur_bal",
    "total_il_high_credit_limit"
]

# %%
df2 = df[features_to_select]

# %%
df2.head()
# Out:
#   loan_status  loan_amnt  int_rate    dti  fico_range_low  fico_range_high  \
# 0  Fully Paid       3600     13.99   5.91             675              679
# 1  Fully Paid      24700     11.99  16.06             715              719
# 2  Fully Paid      20000     10.78  10.78             695              699
# 3  Fully Paid      10400     22.45  25.37             695              699
# 4  Fully Paid      20000      9.17  14.67             680              684
#
#          term  tot_hi_cred_lim  total_acc  total_bal_ex_mort  total_bc_limit  \
# 0   36 months         178050.0         13             7746.0          2400.0
# 1   36 months         314017.0         38            39475.0         79300.0
# 2   60 months         218418.0         18            18696.0          6200.0
# 3   60 months         439570.0         35            95768.0         20300.0
# 4   36 months         388852.0         27           116762.0         31500.0
#
#    total_rec_late_fee  percent_bc_gt_75  avg_cur_bal  \
# 0                 0.0               0.0        20701
# 1                 0.0               7.7         9733
# 2                 0.0              50.0        31617
# 3                 0.0              60.0        27644
# 4                 0.0             100.0        30030
#
#    total_il_high_credit_limit
# 0                     13734.0
# 1                     24667.0
# 2                     14877.0
# 3                     88097.0
# 4                     46452.0

# %%
df["loan_status"].unique()
# Out:
# array(['Fully Paid', 'Current', 'Charged Off', 'In Grace Period',
#        'Late (31-120 days)', 'Late (16-30 days)', 'Default', nan],
#       dtype=object)

# %%
# Definir los valores a reemplazar
yes_values = ['Fully Paid', 'Current', 'Late (31-120 days)', 'Late (16-30 days)', 'In Grace Period']
no_values = ['Charged Off', 'Default']

# Reemplazar los valores en la columna
df2['loan_status'] = df2['loan_status'].replace(yes_values, '1').replace(no_values, '0')

# %%
df2.head()
# Out:
#   loan_status  loan_amnt  int_rate    dti  fico_range_low  fico_range_high  \
# 0           1       3600     13.99   5.91             675              679
# 1           1      24700     11.99  16.06             715              719
# 2           1      20000     10.78  10.78             695              699
# 3           1      10400     22.45  25.37             695              699
# 4           1      20000      9.17  14.67             680              684
#
#          term  tot_hi_cred_lim  total_acc  total_bal_ex_mort  total_bc_limit  \
# 0   36 months         178050.0         13             7746.0          2400.0
# 1   36 months         314017.0         38            39475.0         79300.0
# 2   60 months         218418.0         18            18696.0          6200.0
# 3   60 months         439570.0         35            95768.0         20300.0
# 4   36 months         388852.0         27           116762.0         31500.0
#
#    total_rec_late_fee  percent_bc_gt_75  avg_cur_bal  \
# 0                 0.0               0.0        20701
# 1                 0.0               7.7         9733
# 2                 0.0              50.0        31617
# 3                 0.0              60.0        27644
# 4                 0.0             100.0        30030
#
#    total_il_high_credit_limit
# 0                     13734.0
# 1                     24667.0
# 2                     14877.0
# 3                     88097.0
# 4                     46452.0

# %%
df2["loan_status"].unique()
# Out:
# array(['1', '0', nan], dtype=object)

# %%
count_loan_status = df2["loan_status"].value_counts(dropna=False)
print(count_loan_status)
# Out:
# 1      1525353
# 0       209012
# NaN          1
# Name: loan_status, dtype: int64

# %%
df2 = df2.dropna(subset=['loan_status'])

# %%
count_loan_status = df2["loan_status"].value_counts(dropna=False)
print(count_loan_status)
# Out:
# 1    1525353
# 0     209012
# Name: loan_status, dtype: int64

# %%
df2['term'] = df2['term'].str.replace(' months', '')

# %%
df2.head()
# Out:
#   loan_status  loan_amnt  int_rate    dti  fico_range_low  fico_range_high  \
# 0           1       3600     13.99   5.91             675              679
# 1           1      24700     11.99  16.06             715              719
# 2           1      20000     10.78  10.78             695              699
# 3           1      10400     22.45  25.37             695              699
# 4           1      20000      9.17  14.67             680              684
#
#   term  tot_hi_cred_lim  total_acc  total_bal_ex_mort  total_bc_limit  \
# 0   36         178050.0         13             7746.0          2400.0
# 1   36         314017.0         38            39475.0         79300.0
# 2   60         218418.0         18            18696.0          6200.0
# 3   60         439570.0         35            95768.0         20300.0
# 4   36         388852.0         27           116762.0         31500.0
#
#    total_rec_late_fee  percent_bc_gt_75  avg_cur_bal  \
# 0                 0.0               0.0        20701
# 1                 0.0               7.7         9733
# 2                 0.0              50.0        31617
# 3                 0.0              60.0        27644
# 4                 0.0             100.0        30030
#
#    total_il_high_credit_limit
# 0                     13734.0
# 1                     24667.0
# 2                     14877.0
# 3                     88097.0
# 4                     46452.0

# %%
print(df2.dtypes)
# Out:
# loan_status                    object
# loan_amnt                       int64
# int_rate                      float64
# dti                           float64
# fico_range_low                  int64
# fico_range_high                 int64
# term                           object
# tot_hi_cred_lim               float64
# total_acc                       int64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_rec_late_fee            float64
# percent_bc_gt_75              float64
# avg_cur_bal                     int64
# total_il_high_credit_limit    float64
# dtype: object

# %%
df2['term'] = df2['term'].str.replace(' months', '').astype(int)

# %%
print(df2.dtypes)
# Out:
# loan_status                    object
# loan_amnt                       int64
# int_rate                      float64
# dti                           float64
# fico_range_low                  int64
# fico_range_high                 int64
# term                            int64
# tot_hi_cred_lim               float64
# total_acc                       int64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_rec_late_fee            float64
# percent_bc_gt_75              float64
# avg_cur_bal                     int64
# total_il_high_credit_limit    float64
# dtype: object

# %%
df2['loan_status'] = df2['loan_status'].astype(int)

# %%
print(df2.dtypes)
# Out:
# loan_status                     int64
# loan_amnt                       int64
# int_rate                      float64
# dti                           float64
# fico_range_low                  int64
# fico_range_high                 int64
# term                            int64
# tot_hi_cred_lim               float64
# total_acc                       int64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_rec_late_fee            float64
# percent_bc_gt_75              float64
# avg_cur_bal                     int64
# total_il_high_credit_limit    float64
# dtype: object

# %% [markdown]
# ##Balancear etiquetas##

# %% [markdown]
# "loan_status" Label

# %% [markdown]
# **##Insertar un gráfico de barras para mostrar los conteos de observaciones en cada categeria usando barras.##**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df2['loan_status'].value_counts().index, y=df2['loan_status'].value_counts().values)
plt.show()

# %%
df2['loan_status'].value_counts()
# Out:
# 1    1525353
# 0     209012
# Name: loan_status, dtype: int64

# %% [markdown]
# **##Usar función resample https://scikit-learn.org/stable/modules/generated/sklearn.utils.resample.html##**

# %%
from sklearn.utils import resample
#Crear dos diferentes dataframe de una clase mayoritaria y minoritaria
df2_majority = df2[(df2['loan_status']==1)]
df2_minority = df2[(df2['loan_status']==0)]

# muestreo ascendente de la clase minoritaria
df2_minority_upsampled = resample(df2_minority,
                                 replace=True,     # muestra con reemplazo
                                 n_samples= 1576425, # para que coincida con la clase mayoritaria
                                 random_state=0)   # resultados reproducible

# Combinar la clase mayoritaria con la muestra ascendente de la clase minoritaria
df2_upsampled = pd.concat([df2_minority_upsampled, df2_majority])

# %%
sns.barplot(x=df2_upsampled['loan_status'].value_counts().index, y=df2_upsampled['loan_status'].value_counts().values)
plt.show()

# %%
df2_upsampled.shape
# Out:
# (3101778, 15)

# %% [markdown]
# # **Eliminar outliers usando IQR**

# %% [markdown]
# Detectar outlier es tedioso, especialmente cuando se tienen multiples tipos de datos.
#
# Por lo tanto, tenemos diferentes formas de detectar valores atípicos para diferentes tipos de datos.
#
# En cuanto a los datos distribuidos normalmente, podemos obtener el método Z-Score;
#
# Para skewed data, se usa IQR.

# %% [markdown]
# # **IQR es la diferencia entre el cuartil 75th and 25th.**

# %%
def remove_outliers_iqr(df2_upsampled, columns):
    for col in columns:
        q1 = df2_upsampled[col].quantile(0.25)
        q3 = df2_upsampled[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        df2_upsampled = df2_upsampled[(df2_upsampled[col] >= lower_bound) & (df2_upsampled[col] <= upper_bound)]
    return df2_upsampled

# Señale las columnas para remover los outliers
columns_to_check = [
    "loan_status",
    "loan_amnt",
    "int_rate",
    "dti",
    "fico_range_low",
    "fico_range_high",
    "term",
    "tot_hi_cred_lim",
    "total_acc",
    "total_bal_ex_mort",
    "total_bc_limit",
    "total_rec_late_fee",
    "percent_bc_gt_75",
    "avg_cur_bal",
    "total_il_high_credit_limit"
]

# Solicitar la función que remueve los outliers usando IQR
df2_clean = remove_outliers_iqr(df2_upsampled, columns_to_check)

# Mostrar el resultado en el dataframe
df2_clean.head()
# Out:
#          loan_status  loan_amnt  int_rate    dti  fico_range_low  \
# 236642             0      25000     25.89  24.76             665
# 1452883            0      28000     17.56  21.61             690
# 909423             0       3375     15.59  29.05             670
# 1473273            0      15050     13.11  15.17             665
# 1100825            0       8000     17.57   7.05             660
#
#          fico_range_high  term  tot_hi_cred_lim  total_acc  total_bal_ex_mort  \
# 236642               669    60          69376.0         29            59041.0
# 1452883              694    36         234540.0         25            30735.0
# 909423               674    36          12532.0         52             7511.0
# 1473273              669    36         111307.0         21            12821.0
# 1100825              664    36          11300.0         17             5850.0
#
#          total_bc_limit  total_rec_late_fee  percent_bc_gt_75  avg_cur_bal  \
# 236642          12400.0                 0.0              75.0         7380
# 1452883         15300.0                 0.0             100.0        22412
# 909423           1500.0                 0.0              50.0          751
# 1473273          4100.0                 0.0             100.0        16241
# 1100825          6300.0                 0.0              33.3          585
#
#          total_il_high_credit_limit
# 236642                      49376.0
# 1452883                     36452.0
# 909423                       8232.0
# 1473273                     10604.0
# 1100825                         0.0

# %%
df2_upsampled['loan_status'].value_counts()
# Out:
# 0    1576425
# 1    1525353
# Name: loan_status, dtype: int64

# %%
df2['loan_status'].value_counts()
# Out:
# 1    1525353
# 0     209012
# Name: loan_status, dtype: int64

# %%
df2_clean['loan_status'].value_counts()
# Out:
# 0    1070631
# 1    1006782
# Name: loan_status, dtype: int64

# %% [markdown]
# ##Correlación mostrando un heatmap##

# %% [markdown]
# Seaborn es una biblioteca de python que permite hacer mejores gráficos fácilmente gracias a su función heatmap(). Un mapa de calor es una representación gráfica de datos donde cada valor de una matriz se representa como un color.
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(df2_clean.corr(), fmt='.2g', annot=True, annot_kws={"fontsize": 8})
# Out:
# <Axes: >

# %% [markdown]
# ##Definiendo vector de características (X) y variable target (y)##

# %%
X = df2_upsampled.drop('loan_status', axis=1)
y = df2_upsampled['loan_status']

# %% [markdown]
# ##Dividir arrais o matrices en subconjuntos aleatorios de entrenamiento y prueba.
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html##
#
# Para ser precisos, el método split() genera los índices de entrenamiento y prueba, no los datos en si mismos.
#
# Tener múltiples divisiones puede ser útil si desea estimar mejor el rendimiento de su modelo.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %% [markdown]
# # **REGRESION LOGISTICA**

# %% [markdown]
# ##Imputar el modelo##

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state=0)
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = LR.predict(X_test)
print("Accuracy Score :", round(accuracy_score(y_test, y_pred)*100 ,2), "%")
# Out:
# Accuracy Score : 60.07 %

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score
print('F-1 Score : ',(f1_score(y_test, y_pred, average='micro')))
print('Precision Score : ',(precision_score(y_test, y_pred, average='micro')))
print('Recall Score : ',(recall_score(y_test, y_pred, average='micro')))
print('Jaccard Score : ',(jaccard_score(y_test, y_pred, average='micro')))
# Out:
# F-1 Score :  0.6007228107731689
# Precision Score :  0.6007228107731689
# Recall Score :  0.6007228107731689
# Jaccard Score :  0.4293093715799781

# %%
from sklearn.metrics import classification_report

# %%
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.64      0.62    314983
#            1       0.60      0.56      0.58    305373
#
#     accuracy                           0.60    620356
#    macro avg       0.60      0.60      0.60    620356
# weighted avg       0.60      0.60      0.60    620356

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve

# %%
# Matriz de confusión
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_6_test, y_6_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'],
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Blues')
plt.figure(figsize=(9,9))

# %%
# Grupo 1 (ya proporcionado)
features_to_select_1 = ["loan_status","loan_amnt","int_rate","dti","tot_hi_cred_lim","total_bal_ex_mort","total_bc_limit"]

# Grupo 2
features_to_select_2 = ["loan_status","loan_amnt","int_rate","tot_hi_cred_lim","total_bal_ex_mort"]

# Grupo 3
features_to_select_3 = ["loan_status","loan_amnt","int_rate","tot_hi_cred_lim","total_acc","total_bal_ex_mort"]

# Grupo 4
features_to_select_4 = ["loan_status","loan_amnt","int_rate"]

# Grupo 5
features_to_select_5 = ["loan_status","int_rate"]

# Grupo 6
features_to_select_6 = ["loan_status","int_rate","total_rec_late_fee"]

# %%
df3_1 = df2_upsampled[features_to_select_1]
df3_2 = df2_upsampled[features_to_select_2]
df3_3 = df2_upsampled[features_to_select_3]
df3_4 = df2_upsampled[features_to_select_4]
df3_5 = df2_upsampled[features_to_select_5]
df3_6 = df2_upsampled[features_to_select_6]

# %% [markdown]
# ##Definiendo vector de características (X) y variable target (y)##

# %%
X_1 = df3_1.drop('loan_status', axis=1)
y_1 = df3_1['loan_status']

X_2 = df3_2.drop('loan_status', axis=1)
y_2 = df3_2['loan_status']

X_3 = df3_3.drop('loan_status', axis=1)
y_3 = df3_3['loan_status']

X_4 = df3_4.drop('loan_status', axis=1)
y_4 = df3_4['loan_status']

X_5 = df3_5.drop('loan_status', axis=1)
y_5 = df3_5['loan_status']

X_6 = df3_6.drop('loan_status', axis=1)
y_6 = df3_6['loan_status']

# %% [markdown]
# ##Dividir arrais o matrices en subconjuntos aleatorios de entrenamiento y prueba.
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html##
#
# Para ser precisos, el método split() genera los índices de entrenamiento y prueba, no los datos en si mismos.
#
# Tener múltiples divisiones puede ser útil si desea estimar mejor el rendimiento de su modelo.

# %%
X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(X_1,y_1, test_size=0.2,random_state=0)
X_2_train, X_2_test, y_2_train, y_2_test = train_test_split(X_2, y_2, test_size=0.2, random_state=0)
X_3_train, X_3_test, y_3_train, y_3_test = train_test_split(X_3, y_3, test_size=0.2, random_state=0)
X_4_train, X_4_test, y_4_train, y_4_test = train_test_split(X_4, y_4, test_size=0.2, random_state=0)
X_5_train, X_5_test, y_5_train, y_5_test = train_test_split(X_5, y_5, test_size=0.2, random_state=0)
X_6_train, X_6_test, y_6_train, y_6_test = train_test_split(X_6, y_6, test_size=0.2, random_state=0)

# %%
LR1 = LogisticRegression()
LR1.fit(X_1_train, y_1_train)

LR2 = LogisticRegression()
LR2.fit(X_2_train, y_2_train)

LR3 = LogisticRegression()
LR3.fit(X_3_train, y_3_train)

LR4 = LogisticRegression()
LR4.fit(X_4_train, y_4_train)

LR5 = LogisticRegression()
LR5.fit(X_5_train, y_5_train)

LR6 = LogisticRegression()
LR6.fit(X_6_train, y_6_train)
# Out:
# LogisticRegression()

# %%
y_pred = LR1.predict(X_1_test)
print("Accuracy Score for Group 1:", round(accuracy_score(y_1_test, y_pred)*100 ,2), "%")

y_pred_2 = LR2.predict(X_2_test)
print("Accuracy Score for Group 2:", round(accuracy_score(y_2_test, y_pred_2)*100 ,2), "%")

y_pred_3 = LR3.predict(X_3_test)
print("Accuracy Score for Group 3:", round(accuracy_score(y_3_test, y_pred_3)*100 ,2), "%")

y_pred_4 = LR4.predict(X_4_test)
print("Accuracy Score for Group 4:", round(accuracy_score(y_4_test, y_pred_4)*100 ,2), "%")

y_pred_5 = LR5.predict(X_5_test)
print("Accuracy Score for Group 5:", round(accuracy_score(y_5_test, y_pred_5)*100 ,2), "%")

y_pred_6 = LR6.predict(X_6_test)
print("Accuracy Score for Group 6:", round(accuracy_score(y_6_test, y_pred_6)*100 ,2), "%")
# Out:
# Accuracy Score for Group 1: 59.35 %
# Accuracy Score for Group 2: 56.37 %
# Accuracy Score for Group 3: 56.37 %
# Accuracy Score for Group 4: 62.55 %
# Accuracy Score for Group 5: 62.05 %
# Accuracy Score for Group 6: 63.96 %

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Establecer estilo de seaborn
sns.set(style="ticks")

# %%
# Documentar sns.boxplot: https://seaborn.pydata.org/generated/seaborn.boxplot.html

num_vars = [
    "loan_status",
    "loan_amnt",
    "int_rate",
    "dti",
    "fico_range_low",
    "fico_range_high",
    "term",
    "tot_hi_cred_lim",
    "total_acc",
    "total_bal_ex_mort",
    "total_bc_limit",
    "total_rec_late_fee",
    "percent_bc_gt_75",
    "avg_cur_bal",
    "total_il_high_credit_limit"
]

fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(10, 20))
axs = axs.flatten()

for i, var in enumerate(columns_to_check):
    sns.boxplot(x=var, data=df2, ax=axs[i])

fig.tight_layout()

plt.show()

# %% [markdown]
# # **Instanciar el modelo (Decision tree)**

# %% [markdown]
# Instanciamos el modelo con criterio gini index

# %%
from sklearn.tree import DecisionTreeClassifier
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)

clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
#Hacemos predicción con CLF Gini
y_pred_gini = clf_gini.predict(X_test)

# %%
#Estimamos precisión
print('Precisión en el set de Entrenamiento: {:.4f}'
     .format(clf_gini.score(X_train, y_train)))
print('Precisión en el set de Test: {:.4f}'
     .format(clf_gini.score(X_test, y_test)))
# Out:
# Precisión en el set de Entrenamiento: 0.6412
# Precisión en el set de Test: 0.6407

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score
print('F-1 Score : ',(f1_score(y_test, y_pred_gini, average='micro')))
print('Precision Score : ',(precision_score(y_test, y_pred_gini, average='micro')))
print('Recall Score : ',(recall_score(y_test, y_pred_gini, average='micro')))
print('Jaccard Score : ',(jaccard_score(y_test, y_pred_gini, average='micro')))
# Out:
# F-1 Score :  0.6406643927035445
# Precision Score :  0.6406643927035445
# Recall Score :  0.6406643927035445
# Jaccard Score :  0.47130700414575605

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
print (classification_report(y_test, y_pred_gini))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.82      0.70    314983
#            1       0.71      0.45      0.55    305373
#
#     accuracy                           0.64    620356
#    macro avg       0.66      0.64      0.63    620356
# weighted avg       0.66      0.64      0.63    620356

# %%
# Matriz de confusión
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_6_test, y_6_pred_gini)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'],
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Blues')
plt.figure(figsize=(9,9))

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'x[1] <= 11.985\ngini = 0.5\nsamples = 2481422\nvalue = [1261442, 1219980]'),
#  Text(0.25, 0.625, 'x[10] <= 0.005\ngini = 0.431\nsamples = 820089\nvalue = [257723, 562366]'),
#  Text(0.125, 0.375, 'x[1] <= 7.865\ngini = 0.41\nsamples = 777151\nvalue = [223691, 553460]'),
#  Text(0.0625, 0.125, 'gini = 0.254\nsamples = 207604\nvalue = [30930, 176674]'),
#  Text(0.1875, 0.125, 'gini = 0.448\nsamples = 569547\nvalue = [192761, 376786]'),
#  Text(0.375, 0.375, 'x[10] <= 63.925\ngini = 0.329\nsamples = 42938\nvalue = [34032, 8906]'),
#  Text(0.3125, 0.125, 'gini = 0.316\nsamples = 39758\nvalue = [31954, 7804]'),
#  Text(0.4375, 0.125, 'gini = 0.453\nsamples = 3180\nvalue = [2078, 1102]'),
#  Text(0.75, 0.625, 'x[10] <= 0.005\ngini = 0.478\nsamples = 1661333\nvalue = [1003719, 657614]'),
#  Text(0.625, 0.375, 'x[1] <= 16.17\ngini = 0.488\nsamples = 1507609\nvalue = [871786, 635823]'),
#  Text(0.5625, 0.125, 'gini = 0.5\nsamples = 793227\nvalue = [400232, 392995]'),
#  Text(0.6875, 0.125, 'gini = 0.449\nsamples = 714382\nvalue = [471554, 242828]'),
#  Text(0.875, 0.375, 'x[10] <= 85.67\ngini = 0.243\nsamples = 153724\nvalue = [131933, 21791]'),
#  Text(0.8125, 0.125, 'gini = 0.234\nsamples = 143624\nvalue = [124230, 19394]'),
#  Text(0.9375, 0.125, 'gini = 0.362\nsamples = 10100\nvalue = [7703, 2397]')]

# %% [markdown]
# # **Instanciamos el modelo con criterio gini entropy**

# %%
from sklearn.tree import DecisionTreeClassifier
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %% [markdown]
# # **Predecir con test set para el criterio entropy**

# %%
y_pred_en = clf_en.predict(X_test)

# %%
print('Precisión en el set de Entrenamiento: {:.4f}'
     .format(clf_en.score(X_train, y_train)))
print('Precisión en el set de Test: {:.4f}'
     .format(clf_en.score(X_test, y_test)))
# Out:
# Precisión en el set de Entrenamiento: 0.6412
# Precisión en el set de Test: 0.6407

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score
print('F-1 Score : ',(f1_score(y_test, y_pred_en, average='micro')))
print('Precision Score : ',(precision_score(y_test, y_pred_en, average='micro')))
print('Recall Score : ',(recall_score(y_test, y_pred_en, average='micro')))
print('Jaccard Score : ',(jaccard_score(y_test, y_pred_en, average='micro')))
# Out:
# F-1 Score :  0.6406643927035445
# Precision Score :  0.6406643927035445
# Recall Score :  0.6406643927035445
# Jaccard Score :  0.47130700414575605

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
print (classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.82      0.70    314983
#            1       0.71      0.45      0.55    305373
#
#     accuracy                           0.64    620356
#    macro avg       0.66      0.64      0.63    620356
# weighted avg       0.66      0.64      0.63    620356

# %%
# Matriz de confusión
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_en)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'],
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Reds')
plt.figure(figsize=(9,9))

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'x[1] <= 11.985\nentropy = 1.0\nsamples = 2481422\nvalue = [1261442, 1219980]'),
#  Text(0.25, 0.625, 'x[10] <= 0.005\nentropy = 0.898\nsamples = 820089\nvalue = [257723, 562366]'),
#  Text(0.125, 0.375, 'x[1] <= 7.865\nentropy = 0.866\nsamples = 777151\nvalue = [223691, 553460]'),
#  Text(0.0625, 0.125, 'entropy = 0.607\nsamples = 207604\nvalue = [30930, 176674]'),
#  Text(0.1875, 0.125, 'entropy = 0.923\nsamples = 569547\nvalue = [192761, 376786]'),
#  Text(0.375, 0.375, 'x[10] <= 63.925\nentropy = 0.737\nsamples = 42938\nvalue = [34032, 8906]'),
#  Text(0.3125, 0.125, 'entropy = 0.714\nsamples = 39758\nvalue = [31954, 7804]'),
#  Text(0.4375, 0.125, 'entropy = 0.931\nsamples = 3180\nvalue = [2078, 1102]'),
#  Text(0.75, 0.625, 'x[10] <= 0.005\nentropy = 0.968\nsamples = 1661333\nvalue = [1003719, 657614]'),
#  Text(0.625, 0.375, 'x[1] <= 16.17\nentropy = 0.982\nsamples = 1507609\nvalue = [871786, 635823]'),
#  Text(0.5625, 0.125, 'entropy = 1.0\nsamples = 793227\nvalue = [400232, 392995]'),
#  Text(0.6875, 0.125, 'entropy = 0.925\nsamples = 714382\nvalue = [471554, 242828]'),
#  Text(0.875, 0.375, 'x[10] <= 85.67\nentropy = 0.589\nsamples = 153724\nvalue = [131933, 21791]'),
#  Text(0.8125, 0.125, 'entropy = 0.571\nsamples = 143624\nvalue = [124230, 19394]'),
#  Text(0.9375, 0.125, 'entropy = 0.791\nsamples = 10100\nvalue = [7703, 2397]')]

# %% [markdown]
# # **El modelo funciona con un 64% tanto para Gini como Entropy.**

# %% [markdown]
# # **Detectar importancia de las variables:**

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": clf_gini.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,8))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Top 10 Feature Importance Each Attributes (Decision Tree)', fontsize=18)
plt.xlabel ('Importance', fontsize=16)
plt.ylabel ('Feature Name', fontsize=16)
plt.show()

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.43.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.43.0 slicer-0.0.7

# %%
import shap
explainer = shap.TreeExplainer(clf_gini)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# Podemos observar que Decision tree nos identifica 2 variables importantes que es Int_rate y total_rec_late_fee, los cuales corrimos nuevamente en LR logrando 63.7%

# %% [markdown]
# # **Algoritmo de ensamble (Boosting) XGBoost**
# Boosting es un enfoque de Machine Learning basado en la idea de crear una regla de predicción altamente precisa combinando muchas reglas relativamente débiles e imprecisas. El Boosting asume la disponibilidad de un algoritmo de aprendizaje base o débil que, dado ejemplos de entrenamiento etiquetados, produce un clasificador base o débil. La idea fundamental detrás de Boosting es elegir conjuntos de entrenamiento para el algoritmo de aprendizaje base de tal manera que lo obligue a inferir algo nuevo sobre los datos cada vez que se lo ejecute.

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)

# %%
from xgboost import XGBClassifier

# %%
#n_estimators=100 specifies how many times to go through the modeling cycle described above.
# You can experiment with your dataset to find the ideal. Typical values range from 100-1000,
# though this depends a lot on the learning rate discussed below.
#learning_rate parameter can be set to control the weighting of new trees added to the model.

xgb = XGBClassifier(n_estimators=1000, learning_rate=0.001)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
print('Precisión en el set de Entrenamiento: {:.3f}'
     .format(xgb.score(X_train, y_train)))
print('Precisión en el set de Test: {:.3f}'
     .format(xgb.score(X_test, y_test)))
# Out:
# Precisión en el set de Entrenamiento: 0.674
# Precisión en el set de Test: 0.674

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score
print('F-1 Score : ',(f1_score(y_test, y_pred, average='micro')))
print('Precision Score : ',(precision_score(y_test, y_pred, average='micro')))
print('Recall Score : ',(recall_score(y_test, y_pred, average='micro')))
print('Jaccard Score : ',(jaccard_score(y_test, y_pred, average='micro')))
# Out:
# F-1 Score :  0.6735390646660949
# Precision Score :  0.6735390646660949
# Recall Score :  0.6735390646660949
# Jaccard Score :  0.5077715044028398

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.73      0.69    314983
#            1       0.69      0.62      0.65    305373
#
#     accuracy                           0.67    620356
#    macro avg       0.67      0.67      0.67    620356
# weighted avg       0.67      0.67      0.67    620356

# %%
# Matriz de confusión
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'],
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='Reds')
plt.figure(figsize=(9,9))

# %%
xgb.fit(X_6_train, y_6_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xgb.predict(X_6_test)

# %%
print('Precisión en el set de Entrenamiento: {:.3f}'
     .format(xgb.score(X_6_train, y_6_train)))
print('Precisión en el set de Test: {:.3f}'
     .format(xgb.score(X_6_test, y_6_test)))
# Out:
# Precisión en el set de Entrenamiento: 0.672
# Precisión en el set de Test: 0.671
