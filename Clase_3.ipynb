# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Clase_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
da = {'Company': ['Ford', 'Ford', 'VW', 'BMW', 'Cooper', 'Cooper'],
      'Stars': [1, 2, np.nan, 2, 1, 1],
      'Weight': [2, 4, 4, 2, 3, None],
      'Origin': ['China', 'China', 'Mexico', 'Mexico', None, pd.NaT],
      'Lenght': [40, 50, 30, np.nan, 45, pd.NaT],
      'Nones': [None, None, None, None, None, None]
      }
da
# Out:
# {'Company': ['Ford', 'Ford', 'VW', 'BMW', 'Cooper', 'Cooper'],
#  'Stars': [1, 2, nan, 2, 1, 1],
#  'Weight': [2, 4, 4, 2, 3, None],
#  'Origin': ['China', 'China', 'Mexico', 'Mexico', None, NaT],
#  'Lenght': [40, 50, 30, nan, 45, NaT],
#  'Nones': [None, None, None, None, None, None]}

# %%
df = pd.DataFrame (data = da)
df
# Out:
#   Company  Stars  Weight  Origin Lenght Nones
# 0    Ford    1.0     2.0   China     40  None
# 1    Ford    2.0     4.0   China     50  None
# 2      VW    NaN     4.0  Mexico     30  None
# 3     BMW    2.0     2.0  Mexico    NaN  None
# 4  Cooper    1.0     3.0    None     45  None
# 5  Cooper    1.0     NaN     NaT    NaT  None

# %%
type(da)
# Out:
# dict

# %%
# %ls   #Nos dice que carpeta estamos ubicados en colab
# Out:
# sample_data/

# %%
df.to_csv('sample_data/coches.csv')

# %%
# %ls sample_data/
# Out:
# anscombe.json*                coches.csv             README.md*
# california_housing_test.csv   mnist_test.csv
# california_housing_train.csv  mnist_train_small.csv

# %%
df.isnull().any()   #Existe al menos un dato perdido
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Lenght      True
# Nones       True
# dtype: bool

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght Nones
# 0    Ford    1.0     2.0   China     40  None
# 1    Ford    2.0     4.0   China     50  None
# 2      VW    NaN     4.0  Mexico     30  None
# 3     BMW    2.0     2.0  Mexico    NaN  None
# 4  Cooper    1.0     3.0    None     45  None
# 5  Cooper    1.0     NaN     NaT    NaT  None

# %%
df.dropna() #Elimina un renglón si tiene al menos 1 dato perdido.
# Out:
# Empty DataFrame
# Columns: [Company, Stars, Weight, Origin, Lenght, Nones]
# Index: []

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght Nones
# 0    Ford    1.0     2.0   China     40  None
# 1    Ford    2.0     4.0   China     50  None
# 2      VW    NaN     4.0  Mexico     30  None
# 3     BMW    2.0     2.0  Mexico    NaN  None
# 4  Cooper    1.0     3.0    None     45  None
# 5  Cooper    1.0     NaN     NaT    NaT  None

# %%
df.dropna(axis=1)
# Out:
#   Company
# 0    Ford
# 1    Ford
# 2      VW
# 3     BMW
# 4  Cooper
# 5  Cooper

# %%
df.dropna(axis=0)  
#dropna() elimina un renglón si tiene por lo menos 1 dato perdido.
#dropna(axis=1) elimina una columna si tiene por lo menos 1 dato perdido.
# Out:
# Empty DataFrame
# Columns: [Company, Stars, Weight, Origin, Lenght, Nones]
# Index: []

# %%
df.dropna(how = 'all', axis = 1, inplace = True) # how= 'all' significa que todos sean dropna, en columna

# %%
df    # df = dataframe
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
df.dropna(thresh = 4)  #Mantiene el renglón si tiene al menos 4 datos válidos.
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45

# %% [markdown]
# Imprime todos los renglones con al menos un dato perdido.

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
df.isnull().any(axis = 1 )
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
df[df.isnull().any(axis = 1 )]
# Out:
#   Company  Stars  Weight  Origin Lenght
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
df.dropna(thresh=5)
# Out:
#   Company  Stars  Weight Origin Lenght
# 0    Ford    1.0     2.0  China     40
# 1    Ford    2.0     4.0  China     50

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    NaN     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
sm = df.Stars.mean()   #mean = promedio,   sm = Stars Mean,   estamos sacando el promedio de la columna de Stars.

# %%
sm
# Out:
# 1.4

# %%
df['Stars'].fillna(value = sm, inplace = True)

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    1.4     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     NaN     NaT    NaT

# %%
wm = df.Weight.mean()    #mean = promedio,   wm = Weight Mean,   estamos sacando el promedio de la columna de Weight
wm
# Out:
# 3.0

# %%
df['Weight'].fillna(value= wm, inplace = True)

# %%
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    1.4     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0    None     45
# 5  Cooper    1.0     3.0     NaT    NaT

# %%
om = df.Origin.mode() [1]   #mode = moda,   om = Origin Mode,   estamos sacando la moda de la columna de Origin
om
# Out:
# 'Mexico'

# %%
df['Origin'].fillna(value= om, inplace = True)
df
# Out:
#   Company  Stars  Weight  Origin Lenght
# 0    Ford    1.0     2.0   China     40
# 1    Ford    2.0     4.0   China     50
# 2      VW    1.4     4.0  Mexico     30
# 3     BMW    2.0     2.0  Mexico    NaN
# 4  Cooper    1.0     3.0  Mexico     45
# 5  Cooper    1.0     3.0  Mexico    NaT

# %%
lm = df.Lenght.mean()
lm
# Out:
# 41.25

# %%
df['Lenght'].fillna(value = lm, inplace = True)

# %%
df
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    1.0     2.0   China   40.00
# 1    Ford    2.0     4.0   China   50.00
# 2      VW    1.4     4.0  Mexico   30.00
# 3     BMW    2.0     2.0  Mexico   41.25
# 4  Cooper    1.0     3.0  Mexico   45.00
# 5  Cooper    1.0     3.0  Mexico   41.25

# %%
df2 = [20, 20, 20, 22, 24, 25, 29, 29, 23, 60]
df2
# Out:
# [20, 20, 20, 22, 24, 25, 29, 29, 23, 60]

# %%
df
# Out:
#   Company  Stars  Weight  Origin  Lenght
# 0    Ford    1.0     2.0   China   40.00
# 1    Ford    2.0     4.0   China   50.00
# 2      VW    1.4     4.0  Mexico   30.00
# 3     BMW    2.0     2.0  Mexico   41.25
# 4  Cooper    1.0     3.0  Mexico   45.00
# 5  Cooper    1.0     3.0  Mexico   41.25

# %%
x = pd.pivot_table(df,                     
               index= 'Origin',
               aggfunc = ['sum','mean','median'],
               values = 'Lenght',
               margins = True  ,
               columns = 'Company'             
               )

# %%
x
# Out:
#            sum                             mean                              \
# Company    BMW Cooper  Ford    VW    All    BMW  Cooper  Ford    VW     All
# Origin
# China      NaN    NaN  90.0   NaN   90.0    NaN     NaN  45.0   NaN  45.000
# Mexico   41.25  86.25   NaN  30.0  157.5  41.25  43.125   NaN  30.0  39.375
# All      41.25  86.25  90.0  30.0  247.5  41.25  43.125  45.0  30.0  41.250
#
#         median
# Company    BMW  Cooper  Ford    VW    All
# Origin
# China      NaN     NaN  45.0   NaN  45.00
# Mexico   41.25  43.125   NaN  30.0  41.25
# All      41.25  43.125  45.0  30.0  41.25

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.index
# Out:
# Index(['China', 'Mexico', 'All'], dtype='object', name='Origin')

# %%
x.columns
# Out:
# MultiIndex([(   'sum',    'BMW'),
#             (   'sum', 'Cooper'),
#             (   'sum',   'Ford'),
#             (   'sum',     'VW'),
#             (   'sum',    'All'),
#             (  'mean',    'BMW'),
#             (  'mean', 'Cooper'),
#             (  'mean',   'Ford'),
#             (  'mean',     'VW'),
#             (  'mean',    'All'),
#             ('median',    'BMW'),
#             ('median', 'Cooper'),
#             ('median',   'Ford'),
#             ('median',     'VW'),
#             ('median',    'All')],
#            names=[None, 'Company'])

# %%
x[('sum','All')]
# Out:
# Origin
# China      90.0
# Mexico    157.5
# All       247.5
# Name: (sum, All), dtype: float64

# %% [markdown]
# What is the Average birth2010 in Winsconsin?? (data en github, census.csv)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/tkdforever18/Carlos/main/Datasets-main/datasets/census.csv?token=GHSAT0AAAAAAB5NVLATQKN6TBFCTAPPFMGSY6TFZMQ")

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df[df['STNAME'] =='Wisconsin']
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME           CTYNAME  \
# 3096      40       2         3     55       0  Wisconsin         Wisconsin
# 3097      50       2         3     55       1  Wisconsin      Adams County
# 3098      50       2         3     55       3  Wisconsin    Ashland County
# 3099      50       2         3     55       5  Wisconsin     Barron County
# 3100      50       2         3     55       7  Wisconsin   Bayfield County
# ...      ...     ...       ...    ...     ...        ...               ...
# 3164      50       2         3     55     133  Wisconsin   Waukesha County
# 3165      50       2         3     55     135  Wisconsin    Waupaca County
# 3166      50       2         3     55     137  Wisconsin   Waushara County
# 3167      50       2         3     55     139  Wisconsin  Winnebago County
# 3168      50       2         3     55     141  Wisconsin       Wood County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
census = pd.pivot_table(df,                     
               index= 'STNAME',
               aggfunc = 'mean',
               values = 'BIRTHS2010',
               margins = True  ,            
               )  # Margins = True pone totales a la pivote

# %%
census
# Out:
#                        BIRTHS2010
# STNAME
# Alabama                418.411765
# Alaska                 192.800000
# Arizona               2617.125000
# Arkansas               248.394737
# California            4180.474576
# Colorado               516.646154
# Connecticut           2108.666667
# Delaware              1423.500000
# District of Columbia  2243.000000
# Florida               1496.235294
# Georgia                406.112500
# Hawaii                1548.666667
# Idaho                  265.377778
# Illinois               812.349515
# Indiana                450.774194
# Iowa                   199.340000
# Kansas                 188.528302
# Kentucky               226.297521
# Louisiana              448.400000
# Maine                  405.058824
# Maryland              1476.880000
# Massachusetts         2486.266667
# Michigan               692.904762
# Minnesota              397.727273
# Mississippi            227.012048
# Missouri               327.793103
# ...

# %%
census.loc['Wisconsin', : ]
# Out:
# BIRTHS2010    481.041096
# Name: Wisconsin, dtype: float64
