# %% [markdown]
# <a href="https://colab.research.google.com/github/tkdforever18/Carlos/blob/main/Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = "https://raw.githubusercontent.com/tkdforever18/Carlos/main/Datasets-main/datasets/Cartwheeldata.csv?token=GHSAT0AAAAAAB5NVLASF4WKWZ3ZPQOXVWHYY6J7Z6Q"

# %%
import pandas as pd

# %%
df = pd.read_csv(path)
df.head()
#df = dataframe = tabla
#pd = panda
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-0ec6c29d7ecd> in <module>
# ----> 1 df = pd.read_csv(path)
#       2 df.head()
#       3 #df = dataframe = tabla
#       4 #pd = panda
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
path2 = "/content/drive/MyDrive/Canada.xlsx"

# %%
final = pd.read_excel(path2,sheet_name = 'Canada by Citizenship',skiprows = 20)
final.head()
final
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2004    2005  \
# 0      Southern Asia  902  Developing regions      16  ...    2978    3436
# ...

# %%
final.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
no_favs = ['Type', 'Coverage',     'AREA',      'REG',      'DEV',  'DevName']

# %%
final.drop(no_favs, axis = 1, inplace = True)

# %%
final.head(2)

# %%
final.columns

# %%
new_names = {'OdName':'Country', 'AreaName':'Continent',  'RegName':'Region',}

# %%
final.rename(columns = new_names, inplace = True)
final.head(2)

# %%
final['Total'] = final.iloc[ : , 3: ].sum(axis = 1)
final.head(2) 
#iloc llama matriz pero con números [row:row,col:col]

# %%
final.loc[0, 'Total']

# %%
final.set_index('Country', inplace = True)
final.head(2)

# %%
favs = ['India', 'China']

# %%
final.loc[favs, : ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-21c470d3b018> in <module>
# ----> 1 final.loc[favs, : ]
#
# NameError: name 'final' is not defined

# %%
final.iloc[:, -4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4c4d78534e6c> in <module>
# ----> 1 final.iloc[:, -4]
#
# NameError: name 'final' is not defined

# %%
final.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
final.iloc[:, -4:]
# Out:
#        2010    2011    2012    2013
# 0      1758    2203    2635    2004
# 1       561     539     620     603
# 2      4752    4325    3774    4331
# 3         0       0       0       0
# 4         0       0       1       1
# ..      ...     ...     ...     ...
# 192     211     160     174     217
# 193     102      69      46      59
# 194     494     434     437     407
# 195    3731    2554    1681    1484
# 196  280687  248748  257903  259021
#
# [197 rows x 4 columns]

# %%
final.iloc[:, 24:]
# Out:
#        1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0      1537    2212    2555    1999    2395    3326    4067    3697    3479
# 1        63     113     307     574    1264    1816    1602    1021     853
# 2      1106    2054    1842    2292    2389    2867    3418    3406    3072
# 3         0       0       0       0       0       0       0       0       0
# 4         0       0       0       2       0       0       1       0       2
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 192      73     144     121     141     134     122     181     171     113
# 193      41      34      72      34      51      39      78      50      46
# 194      58      39      44      43      49      98     110     191     669
# 195   25152   25986   23151   13468   10132   10743    7993    5938    4052
# 196  212864  226071  216036  174195  189950  227455  250636  229049  221349
#
# ...

# %%
type(-4.0)
# Out:
# float

# %%
type(bool("Yes"))
# Out:
# bool

# %%
type(bool("Yes"))
# Out:
# bool

# %%
type(final)
# Out:
# pandas.core.frame.DataFrame

# %%
final.iloc[:,[1, 2, 3]]
# Out:
#        Coverage          OdName  AREA
# 0    Foreigners     Afghanistan   935
# 1    Foreigners         Albania   908
# 2    Foreigners         Algeria   903
# 3    Foreigners  American Samoa   909
# 4    Foreigners         Andorra   908
# ..          ...             ...   ...
# 192  Foreigners           Yemen   935
# 193  Foreigners          Zambia   903
# 194  Foreigners        Zimbabwe   903
# 195  Foreigners         Unknown   999
# 196        Both           Total   999
#
# [197 rows x 3 columns]

# %%
final.loc[:,['Coverage', 'OdName', 'AREA']]
# Out:
#        Coverage          OdName  AREA
# 0    Foreigners     Afghanistan   935
# 1    Foreigners         Albania   908
# 2    Foreigners         Algeria   903
# 3    Foreigners  American Samoa   909
# 4    Foreigners         Andorra   908
# ..          ...             ...   ...
# 192  Foreigners           Yemen   935
# 193  Foreigners          Zambia   903
# 194  Foreigners        Zimbabwe   903
# 195  Foreigners         Unknown   999
# 196        Both           Total   999
#
# [197 rows x 3 columns]
